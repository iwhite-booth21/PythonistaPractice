# %%
# Ready for tomorrow's session on 11/16/25
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels

# %%
credit_data = pd.read_csv('Datasets/credit_train.csv')
credit_data.head()
# Out:
#                                 Loan ID                           Customer ID  \
# 0  14dd8831-6af5-400b-83ec-68e61888a048  981165ec-3274-42f5-a3b4-d104041a9ca9
# 1  4771cc26-131a-45db-b5aa-537ea4ba5342  2de017a3-2e01-49cb-a581-08169e83be29
# 2  4eed4e6a-aa2f-4c91-8651-ce984ee8fb26  5efb2b2b-bf11-4dfd-a572-3761a2694725
# 3  77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a  e777faab-98ae-45af-9a86-7ce5b33b1011
# 4  d4062e70-befa-4995-8643-a0de73938182  81536ad9-5ccf-4eb8-befb-47a4d608658e
#
#   Loan Status Current Loan Amount        Term Credit Score Annual Income  \
# 0  Fully Paid             445,412  Short Term          709     1,167,493
# 1  Fully Paid             262,328  Short Term          NaN           NaN
# 2  Fully Paid          99,999,999  Short Term          741     2,231,892
# 3  Fully Paid             347,666   Long Term          721       806,949
# 4  Fully Paid             176,220  Short Term          NaN           NaN
#
#   Years in current job Home Ownership             Purpose Monthly Debt  \
# 0              8 years  Home Mortgage   Home Improvements     5,214.74
# 1            10+ years  Home Mortgage  Debt Consolidation    33,295.98
# 2              8 years       Own Home  Debt Consolidation    29,200.53
# 3              3 years       Own Home  Debt Consolidation     8,741.90
# 4              5 years           Rent  Debt Consolidation    20,639.70
#
#    Years of Credit History  Months since last delinquent  \
# 0                     17.2                           NaN
# 1                     21.1                           8.0
# 2                     14.9                          29.0
# 3                     12.0                           NaN
# 4                      6.1                           NaN
#
#    Number of Open Accounts  Number of Credit Problems Current Credit Balance  \
# 0                        6                          1                228,190
# 1                       35                          0                229,976
# 2                       18                          1                297,996
# 3                        9                          0                256,329
# 4                       15                          0                253,460
#
#   Maximum Open Credit  Bankruptcies  Tax Liens
# 0             416,746           1.0        0.0
# 1             850,784           0.0        0.0
# 2             750,090           0.0        0.0
# 3             386,958           0.0        0.0
# 4             427,174           0.0        0.0

# %%
credit_data.shape
# Out:
# (100000, 19)

# %%
# Remove NA and Dupes
credit_data = credit_data.drop_duplicates()
credit_data = credit_data.dropna()
credit_data.shape
# Out:
# (31254, 19)

# %%
credit_data.describe().T
# Out:
#                                 count       mean        std  min   25%   50%  \
# Years of Credit History       31254.0  19.102169   6.670789  3.8  14.5  17.8
# Months since last delinquent  31254.0  34.942151  21.923863  0.0  16.0  32.0
# Number of Open Accounts       31254.0  11.508831   4.991969  1.0   8.0  11.0
# Number of Credit Problems     31254.0   0.183720   0.526855  0.0   0.0   0.0
# Bankruptcies                  31254.0   0.113106   0.357000  0.0   0.0   0.0
# Tax Liens                     31254.0   0.038491   0.301167  0.0   0.0   0.0
#
#                                75%    max
# Years of Credit History       22.5   70.5
# Months since last delinquent  51.0  176.0
# Number of Open Accounts       14.0   48.0
# Number of Credit Problems      0.0   15.0
# Bankruptcies                   0.0    7.0
# Tax Liens                      0.0   15.0

# %%
# Monthly data needed to be in a numeric format to be plotted - obj -> float 64
credit_data['MonthlyDebt_clean'] = (
    credit_data['Monthly Debt']
    .str.replace(',', '', regex=False)   # remove commas
    .astype(float)                       # convert to float64
)

# %%
# Doing the same with Annual Income - course may have unique configuration to get around these issues.
credit_data['AnnualIncome_clean'] = credit_data['Annual Income'].str.replace(',', '', regex=True).astype(float)

# %%
# Doing the same with Current Credit Balance  - course may have unique configuration to get around these issues.
credit_data['CurrentCreditBalance_clean'] = credit_data['Current Credit Balance'].str.replace(',', '', regex=True).astype(int)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Doing the same with Number of Credit Problems  - course may have unique configuration to get around these issues.
# ----> 2 credit_data['NumberOfCreditProblems_clean'] = credit_data['Number of Credit Problems'].str.replace(',', '', regex=True).astype(int)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6321, in NDFrame.__getattr__(self, name)
#    6314 if (
#    6315     name not in self._internal_names_set
#    6316     and name not in self._metadata
#    6317     and name not in self._accessors
#    6318     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319 ):
#    6320     return self[name]
# -> 6321 return object.__getattribute__(self, name)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\strings\accessor.py:194, in StringMethods.__init__(self, data)
#     191 def __init__(self, data) -> None:
#     192     from pandas.core.arrays.string_ import StringDtype
# --> 194     self._inferred_dtype = self._validate(data)
#     195     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     196     self._is_string = isinstance(data.dtype, StringDtype)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\strings\accessor.py:248, in StringMethods._validate(data)
#     245 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     247 if inferred_dtype not in allowed_types:
# --> 248     raise AttributeError("Can only use .str accessor with string values!")
#     249 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
# Utilizing styles
sns.set_style('darkgrid')


# Using access level plt
f,ax = plt.subplots(figsize=(12,6))
sns.regplot(x='MonthlyDebt_clean', y='Months since last delinquent', data=credit_data)

# %%
# Using access level plt changing x axis
sns.regplot(x='AnnualIncome_clean', y='MonthlyDebt_clean', data=credit_data)

# %%
# Using access level plt changing x axis (Trying fit regression param)
# Removes linear portion
sns.regplot(x='AnnualIncome_clean', y='MonthlyDebt_clean',fit_reg=False, data=credit_data)

# %%
# Using access level plt changing x axis (Trying scatter param)
# Removes scatter portion
sns.regplot(x='AnnualIncome_clean', y='MonthlyDebt_clean',scatter=False, data=credit_data)

# %%
# Using another y axis value
# Using access level plot
f,ax = plt.subplots(figsize=(12,6))
sns.regplot(x=credit_data['MonthlyDebt_clean'], y=credit_data['CurrentCreditBalance_clean'])
# Out:
# <Axes: xlabel='MonthlyDebt_clean', ylabel='CurrentCreditBalance_clean'>

# %%
# Using lmplot
sns.lmplot(x='MonthlyDebt_clean', y='CurrentCreditBalance_clean', data=credit_data)

# %%
# Using lmplot
# Adding aspect and ci params 
sns.lmplot(x='MonthlyDebt_clean', y='CurrentCreditBalance_clean', data=credit_data, aspect=1.5, ci = None)

# %%
# Using relplot
sns.relplot(x='MonthlyDebt_clean', y='CurrentCreditBalance_clean', data=credit_data, aspect=1.5)

# %%
# Using lmplot - using different data 
# Adding aspect  
sns.lmplot(x='Number of Credit Problems', y='Bankruptcies', data=credit_data, aspect=2)
